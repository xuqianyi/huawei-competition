# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data = np.load("sampleECG.npy")
print(data)
plt.plot(data[1])
# Out:
# [[-0.35975367 -0.33411437 -0.28283575 ... -0.2230107   0.36669335
#    3.0417275 ]
#  [-0.2956554  -0.28710896 -0.26574287 ... -1.2870419  -1.1759382
#    1.0931404 ]
#  [ 0.0675681   0.05047523  0.02056271 ... -1.0605614  -1.5391618
#   -1.9451175 ]
#  ...
#  [-0.55204844 -0.5392288  -0.5135895  ... -0.7998951   0.12739316
#    2.849433  ]
#  [-2.2314231  -2.154505   -2.073314   ... -0.42385194 -0.25292322
#    1.8238606 ]
#  [ 4.3365126   4.3578787   4.400611   ...  1.9178714   1.8879589
#    3.2553885 ]]
